# %%
import numpy as np
import matplotlib.pyplot as plt

# 빈도수는 막대그래프를 활용 시각적으로 보는게 좋음

# %%
# 데이터 생성
data = np.random.randint(1,7, size=100)
print(data)

# 빈도수 계산
unique, counts = np.unique(data, return_counts=True)
print(unique, counts)

# 막대 그래프 시각화
fig, ax = plt.subplots()
ax.bar(unique, counts)
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_title('Frequency Distribution')
plt.show()
# Out:
# [6 2 4 5 3 3 1 1 1 6 4 6 4 1 3 2 1 6 4 2 1 2 6 2 4 3 4 2 4 6 5 3 2 4 5 5 3
#  6 6 2 1 6 6 4 1 4 2 4 2 1 1 3 3 6 5 4 6 1 5 4 4 3 6 3 4 3 6 3 1 6 5 5 2 3
#  3 6 1 2 3 1 5 2 1 3 5 6 6 1 5 4 4 2 5 2 3 3 6 3 1 1]
# [1 2 3 4 5 6] [18 15 19 17 12 19]
