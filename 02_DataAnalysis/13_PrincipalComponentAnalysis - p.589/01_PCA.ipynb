# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
x = np. random. rand (100, 3)
pca = PCA (n_components = 2)
pca.fit(x)
# Out:
# PCA(n_components=2)

# %%
transformed_data = pca.transform (x)

# %%
explained_var_raito = pca.explained_variance_
print(f'주성분의 설명력 : {explained_var_raito}')
# Out:
# 주성분의 설명력 : [0.10784225 0.09090788]

# %% [markdown]
# - 가장 우월한 주성분을 출력할 수 있다.

# %%
components = pca.components_
print(f'주성분의 가중치 :\n {components}')
# Out:
# 주성분의 가중치 :
#  [[ 0.76567099  0.53955161 -0.3501885 ]
#  [-0.23958189  0.74446442  0.623196  ]]

# %%
plt.scatter(transformed_data[:,0],transformed_data[:,1])
plt.title('PCA result')
plt.show()
